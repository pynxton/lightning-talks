# %% [markdown]
# # Demo of mpld3
#
# adapted from https://github.com/jakevdp/mpld3

# %% [markdown]
# This notebook gives a brief overview of [mpld3](http://mpld3.github.io), a package which allows seamless visualization of matplotlib plots using HTML, Javascript, and the [D3js](http://d3js.org/) package.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# Scatter points
fig, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(size=(2, 200))
color, size = np.random.random((2, 200))

ax.scatter(x, y, c=color, s=400 * size, alpha=0.3)
ax.grid(color='black', alpha=0.7)

# %% [markdown]
# A weakness quickly becomes clear, however: the embedded figure is a simple static PNG image.
#
# This is where mpld3 comes in. Using the simple ``mpld3.display()`` command, we can create a fully interactive visualization of the same plot:

# %%
import mpld3
mpld3.display(fig)
# Out:
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/mpld3/mplexporter/utils.py:21: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if color in ['none', 'None', None]:
# <style>
#
# </style>
#
# <div id="fig226749788752431896522"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# function create_fig226749788752431896522(){
#
#   mpld3.draw_figure("fig226749788752431896522", {"width": 480.0, "axes": [{"xlim": [-3.0, 3.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-3.0, 3.0], "ylim": [-4.0, 3.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"grid": {"color": "#000000", "alpha": 0.7, "dasharray": "2,2", "gridOn": true}, "position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null}, {"grid": {"color": "#000000", "alpha": 0.7, "dasharray": "2,2", "gridOn": true}, "position": "left", "nticks": 8, "tickvalues": null, "tickformat": null}], "lines": [], "markers": [], "id": "226749789712", "ydomain": [-4.0, 3.0], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [1.0], "offsets": "data01", "yindex": 1, "id": "226749788560", "pathtransforms": [[14.622563425285904, 0.0, 0.0, 14.622563425285904, 0.0, 0.0], [16.151047654411755, 0.0, 0.0, 16.151047654411755, 0.0, 0.0], [13.136327766330346, 0.0, 0.0, 13.136327766330346, 0.0, 0.0], [19.644741076627454, 0.0, 0.0, 19.644741076627454, 0.0, 0.0], [19.258112273121355, 0.0, 0.0, 19.258112273121355, 0.0, 0.0], [21.398186231814517, 0.0, 0.0, 21.398186231814517, 0.0, 0.0], [3.781210794843662, 0.0, 0.0, 3.781210794843662, 0.0, 0.0], [21.03132632568342, 0.0, 0.0, 21.03132632568342, 0.0, 0.0], [13.923402246030456, 0.0, 0.0, 13.923402246030456, 0.0, 0.0], [20.827006391927284, 0.0, 0.0, 20.827006391927284, 0.0, 0.0], [18.469658484166487, 0.0, 0.0, 18.469658484166487, 0.0, 0.0], [22.081205427307346, 0.0, 0.0, 22.081205427307346, 0.0, 0.0], [19.3637366524138, 0.0, 0.0, 19.3637366524138, 0.0, 0.0], [13.417229130087827, 0.0, 0.0, 13.417229130087827, 0.0, 0.0], [15.730181304391039, 0.0, 0.0, 15.730181304391039, 0.0, 0.0], [13.633458392876582, 0.0, 0.0, 13.633458392876582, 0.0, 0.0], [13.423985094336075, 0.0, 0.0, 13.423985094336075, 0.0, 0.0], [11.35084702079154, 0.0, 0.0, 11.35084702079154, 0.0, 0.0], [15.650035228508763, 0.0, 0.0, 15.650035228508763, 0.0, 0.0], [18.348343284035767, 0.0, 0.0, 18.348343284035767, 0.0, 0.0], [11.702912401161349, 0.0, 0.0, 11.702912401161349, 0.0, 0.0], [16.092016440600382, 0.0, 0.0, 16.092016440600382, 0.0, 0.0], [7.613512813949707, 0.0, 0.0, 7.613512813949707, 0.0, 0.0], [8.884590262107002, 0.0, 0.0, 8.884590262107002, 0.0, 0.0], [4.80772807473416, 0.0, 0.0, 4.80772807473416, 0.0, 0.0], [21.894600977992216, 0.0, 0.0, 21.894600977992216, 0.0, 0.0], [1.3807050462789996, 0.0, 0.0, 1.3807050462789996, 0.0, 0.0], [9.390827362218452, 0.0, 0.0, 9.390827362218452, 0.0, 0.0], [17.39684593404321, 0.0, 0.0, 17.39684593404321, 0.0, 0.0], [6.338968208805714, 0.0, 0.0, 6.338968208805714, 0.0, 0.0], [20.868743277297376, 0.0, 0.0, 20.868743277297376, 0.0, 0.0], [18.851206305734834, 0.0, 0.0, 18.851206305734834, 0.0, 0.0], [21.845585721717, 0.0, 0.0, 21.845585721717, 0.0, 0.0], [15.833010479995172, 0.0, 0.0, 15.833010479995172, 0.0, 0.0], [12.1797987609009, 0.0, 0.0, 12.1797987609009, 0.0, 0.0], [16.472956855198174, 0.0, 0.0, 16.472956855198174, 0.0, 0.0], [21.439765952495016, 0.0, 0.0, 21.439765952495016, 0.0, 0.0], [16.03640052654686, 0.0, 0.0, 16.03640052654686, 0.0, 0.0], [11.487127134690919, 0.0, 0.0, 11 ...

# %% [markdown]
# Notice that as you hover over the plot, a toolbar appears in the lower left. This has tools to enable panning and zooming, and a button to reset the view once you've explored the plot.

# %%
from mpld3 import plugins

fig, ax = plt.subplots()
points = ax.scatter(np.random.rand(40), np.random.rand(40),
 s=300, alpha=0.3)

labels = ["Point {0}".format(i) for i in range(40)]
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)

# %% [markdown]
# If you'd like to use mpld3 by default for every figure you generate, you can call the following command:

# %%
# the previous plot is not interactive; you need to call this command before 
mpld3.enable_notebook()

# %%
from mpld3 import plugins

fig, ax = plt.subplots()
X, Y = np.random.rand(40), np.random.rand(40)
points = ax.scatter(X, Y, s=300, alpha=0.3)

labels = ["Point {0}:({1},{2})".format(i, int(X[i]*100)/100., int(Y[i]*100)/100.) for i in range(40)]
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)

# %% [markdown]
# ## Other Plot Types

# %% [markdown]
# Nearly any type of plot matplotlib can do, mpld3 can visualize as well. Below are some examples:

# %% [markdown]
# ### A Histogram

# %%
# Histogram with modified axes/grid
fig = plt.figure()

ax = fig.add_subplot(111, axisbg='#EEEEEE')
ax.grid(color='white', linestyle='solid')

x = np.random.normal(size=1000)
ax.hist(x, 30, histtype='stepfilled', fc='lightblue', alpha=0.5);

# %% [markdown]
# ### Multiple Subplots with linked axes

# %%
# multiple subplots, shared axes
fig, ax = plt.subplots(2, 2, figsize=(8, 6),sharex='col', sharey='row')
fig.subplots_adjust(hspace=0.3)

np.random.seed(0)

for axi in ax.flat:
 color = np.random.random(3)
 axi.plot(np.random.random(30), lw=2, c=color)
 axi.set_title("RGB = ({0:.2f}, {1:.2f}, {2:.2f})".format(*color),
 size=14)
 axi.grid(color='lightgray', alpha=0.7)

# %% [markdown]
# ## For More Information

# %% [markdown]
# More examples, documentation, and information can be found on the [mpld3 website](http://mpld3.github.io). See especially the [Example Gallery](http://mpld3.github.io/examples/index.html) and the [Notebook Gallery](http://mpld3.github.io/notebooks/index.html). If you are interested in contributing, the source of mpld3 can be found on [GitHub](http://github.com/jakevdp/mpld3).
